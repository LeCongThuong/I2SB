# %%
import numpy as np
from matplotlib import pyplot as plt

np_path = "/mnt/hmi/thuong/I2SB/results/vanila_exp/samples_nfe999_clip/01417_mk7_70.npy"
np_path_2 = "/mnt/hmi/thuong/I2SB/results/aux_losses/samples_nfe999_clip/01417_mk7_70.npy"
np_path_3 = "/mnt/hmi/thuong/wb_train_val_test_dataset/subtest/np_depth_512/01417_mk7_70.npy"

np_img = np.load(np_path)
np_img_2 = np.load(np_path_2)
np_img_3 = np.load(np_path_3)

fig, axes = plt.subplots(nrows=1, ncols=3)
axes[0].imshow(np_img, cmap='gray')
axes[1].imshow(np_img_2, cmap='gray')
axes[2].imshow(np_img_3, cmap='gray')
