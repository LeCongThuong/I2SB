# %%
import numpy as np
from matplotlib import pyplot as plt

np_path = "/mnt/hmi/thuong/I2SB/results/vanila_exp/samples_nfe999_clip/01853_mk9_146.npy"
np_path_2 = "/mnt/hmi/thuong/I2SB/results/aux_losses/samples_nfe999_clip/01853_mk9_146.npy"

np_img = np.load(np_path)
np_img_2 = np.load(np_path_2)

fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(np_img, cmap='gray')
axes[1].imshow(np_img_2, cmap='gray')
